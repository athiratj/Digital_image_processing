# %% [markdown]
# # SciPy India 2020
# # Workshop on Digital Image Processing using Google Colab
# 19th December 2020
# # Image Processing using OpenCV

# %% [markdown]
# List of Exercises
#
#
# *   Reading an image and display
# *   Displaying size and title of an image
#
#
# *   Getting image file informations: dimension, dtype, size in bytes
# *   Split R,G,B matrices of an image and merging the individual matrices to get original image
#
#
# *   Converting colour image into Gray scale image
# *   Vertical stack and Horizontal stack - more than one image
#
# *   Rotating an image
# *   Image cropping
#
# *   Displaying text on an image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In Colab, we can’t use the standard imshow function. Google Colab crashes if it uses the standard function, instead of import from google.colab.patches import cv2_imshow and display using cv2_imshow(image)

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/Bird1.jpg");

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=185x123 at 0x7F29E1ED35C0>

# %%
img1=cv2.imread("/content/Bird1.jpg",1)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=185x123 at 0x7F29E1E4C4A8>

# %%
print(type(img))
print(img.shape[0:2])
cv2_imshow(img)
print('original image')
# Out:
# <class 'numpy.ndarray'>
# (123, 185)
# <PIL.Image.Image image mode=RGB size=185x123 at 0x7F29E1DDC160>
# original image

# %%
# To print the shape of the image
print(img.shape)
# Out:
# (123, 185, 3)

# %%
# To print size of the image
print(img.size)
# Out:
# 68265

# %%
#To print type of image
print(img.dtype)
# Out:
# uint8

# %%
# Splitting image gives blue green red channels
B,G,R = cv2.split(img)

# %%
# Merging the individual channels into image
img2 = cv2.merge([B,G,R])

# %%
cv2_imshow(img2)
print('Merged Image')
# Out:
# <PIL.Image.Image image mode=RGB size=185x123 at 0x7F29E1DDC160>
# Merged Image

# %%
grey = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
cv2_imshow(grey)
print('Gray Image')
# Out:
# <PIL.Image.Image image mode=L size=185x123 at 0x7F29E1DDC390>
# Gray Image

# %%
grey_3_channel = cv2.cvtColor(grey, cv2.COLOR_GRAY2BGR)
numpy_vertical = np.vstack((img,grey_3_channel))
numpy_horizontal = np.hstack((img,grey_3_channel))
cv2_imshow(img)
print("original image")
cv2_imshow(grey)
print("gray image")
cv2_imshow(numpy_vertical)
print("Numpy Vertical")
cv2_imshow(numpy_horizontal)
print("Numpy Horizontal")
# Out:
# <PIL.Image.Image image mode=RGB size=185x123 at 0x7F29E1DDCCC0>
# original image
# <PIL.Image.Image image mode=L size=185x123 at 0x7F29E1DDCC18>
# gray image
# <PIL.Image.Image image mode=RGB size=185x246 at 0x7F29E1DDCD30>
# Numpy Vertical
# <PIL.Image.Image image mode=RGB size=370x123 at 0x7F29E1DDCCF8>
# Numpy Horizontal

# %%
img3 = cv2.imread('/content/Bird2.jpg')
height,width =img3.shape[0:2]
rotationMatrix = cv2.getRotationMatrix2D((width/2, height/2),270,1)
rotatedImage = cv2.warpAffine(img3,rotationMatrix,(width, height))
cv2_imshow(img3)
print('originalImage')
cv2_imshow(rotatedImage)
print('rotated to 270 degrees')
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F29E1DDCD68>
# originalImage
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F29E1DDCC18>
# rotated to 270 degrees

# %%
height,width = img3.shape[0:2]
startRow =int(height*0.2)
endRow = int(height*0.8)
startCol = int(width*0.2)
endCol = int(width*0.8)
croppedImage = img3[startRow:endRow, startCol:endCol]
cv2_imshow(img3)
print('Original Image')
cv2_imshow(croppedImage)
print('Cropped Image')
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F29E1DED048>
# Original Image
# <PIL.Image.Image image mode=RGB size=165x110 at 0x7F29E1DED048>
# Cropped Image

# %%
font= cv2.FONT_ITALIC
img4=cv2.putText(img,'1',(10,50),font,2,(255,255,266))
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=185x123 at 0x7F29E1DDC860>

# %%
cap=cv2.VideoCapture('/content/Bullfinch.mp4')

# %%
while(cap.isOpened()):
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2_imshow(gray)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F29DECF4AC8>
